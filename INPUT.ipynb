# %% [markdown]
# Aula 02 PYTHOn

# %%
nome= input('Digite seu nome: ')
print('Seu nome é: ',nome)
print(f'Olá {nome}, seja bem vindo')
# Out:
# Digite seu nome: LUcas
# Seu nome é:  LUcas
# Olá LUcas, seja bem vindo

# %% [markdown]
# Soma

# %%
num1 = int(input('Digite seu número: '))
num2 = int(input('Digite seu outro número: '))
soma = num1+num2
print('O resultado é: ', soma)
# Out:
# Digite seu número: 5
# Digite seu outro número: 5
# O resultado é:  10

# %% [markdown]
# Subtração

# %%
num1 = int(input('Digite seu número: '))
num2 = int(input('Digite seu outro número: '))
subtracao = num1-num2
print('O resultado é: ', subtracao)
# Out:
# Digite seu número: 5
# Digite seu outro número: 2
# O resultado é:  3

# %% [markdown]
# Cauculadora completa

# %%
num1 = int(input('Digite seu número: '))
num2 = int(input('Digite seu outro número: '))
operacao = input('Escolha sua operação: soma, subtração, multiplicação, divisão')

if operacao == 'soma':
  soma = num1+num2
  print('O resultado é: ', soma)

elif operacao == 'subtração':
  subtracao = num1-num2
  print('O resultado é: ', subtracao)

elif operacao == 'multiplicação':
  multiplicacao = num1*num2
  print('O resultado é: ', multiplicacao)

elif operacao == 'divisão':
  divisao = num1/num2
  print('O resultado é: ', divisao)
# Out:
# Digite seu número: 5
# Digite seu outro número: 6
# Escolha sua operação: soma, subtração, multiplicação, divisãosoma
# O resultado é:  11
