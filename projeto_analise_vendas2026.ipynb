# %% [markdown]
# <a href="https://colab.research.google.com/github/lucaslaurindo/Python/blob/main/projeto_analise_vendas2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto: Análise de Vendas de uma Loja (versão simplificada)
#
# Primeiro contato com pandas. Vamos criar uma tabela de vendas e responder algumas perguntas simples sobre ela.

# %% [markdown]
# ## 1. Importando o pandas

# %%
import pandas as pd

# %% [markdown]
# ## 2. Criando a tabela de vendas

# %%
dados = {
    "produto": ["Caneta", "Caderno", "Lápis", "Borracha", "Mochila", "Estojo"],
    "preco": [2.5, 15.0, 1.0, 1.5, 89.9, 25.0],
    "quantidade": [120, 45, 200, 90, 15, 30]
}

df = pd.DataFrame(dados)
df
# Out:
#     produto  preco  quantidade
# 0    Caneta    2.5         120
# 1   Caderno   15.0          45
# 2     Lápis    1.0         200
# 3  Borracha    1.5          90
# 4   Mochila   89.9          15
# 5    Estojo   25.0          30

# %% [markdown]
# ## 3. Primeira olhada na tabela

# %%
df.head()
# Out:
#     produto  preco  quantidade
# 0    Caneta    2.5         120
# 1   Caderno   15.0          45
# 2     Lápis    1.0         200
# 3  Borracha    1.5          90
# 4   Mochila   89.9          15

# %%
df.shape
# Out:
# (6, 3)

# %% [markdown]
# ## 4. Criando a coluna de faturamento
#
# Faturamento = preço × quantidade

# %%
df['faturamento'] = df['preco'] * df['quantidade']
df
# Out:
#     produto  preco  quantidade  faturamento
# 0    Caneta    2.5         120        300.0
# 1   Caderno   15.0          45        675.0
# 2     Lápis    1.0         200        200.0
# 3  Borracha    1.5          90        135.0
# 4   Mochila   89.9          15       1348.5
# 5    Estojo   25.0          30        750.0

# %% [markdown]
# ## 5. Filtrando produtos com preço acima de R$ 10

# %%
caros = df[df['preco'] >= 10]
caros
# Out:
#    produto  preco  quantidade  faturamento
# 1  Caderno   15.0          45        675.0
# 4  Mochila   89.9          15       1348.5
# 5   Estojo   25.0          30        750.0

# %% [markdown]
# ## 6. Descobrindo o produto mais vendido (em quantidade)

# %%
df.sort_values('quantidade',ascending=False)
# Out:
#     produto  preco  quantidade  faturamento
# 2     Lápis    1.0         200        200.0
# 0    Caneta    2.5         120        300.0
# 3  Borracha    1.5          90        135.0
# 1   Caderno   15.0          45        675.0
# 5    Estojo   25.0          30        750.0
# 4   Mochila   89.9          15       1348.5

# %%
mais_vendido = df.sort_values('quantidade',ascending=False).iloc[0]
print('O produto mais vendido', mais_vendido['produto'])
# Out:
# O produto mais vendido Lápis

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 7. Gráfico simples

# %%
df.plot(x='produto', y='quantidade',kind='bar', legend=False)
plt.title('Quantidade vendida por produto')
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.xticks(rotation=40)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Agora é com vocês!

# %% [markdown]
# **Questão 1:** Qual foi o faturamento total da loja (soma da coluna `faturamento`)?

# %%
faturamento_total = df['faturamento'].sum()
print(f'O faturamento total da loja foi de R${faturamento_total:.2f}')
# Out:
# O faturamento total da loja foi de R$3408.50

# %% [markdown]
# **Questão 2:** Qual foi o produto que MAIS faturou (não é o mesmo que mais vendeu em quantidade)? Dica: use `sort_values` na coluna `faturamento`.

# %%
mais_lucrativo = df.sort_values('faturamento',ascending=False).iloc[0]
print('O produto com maior faturamento', mais_lucrativo['produto'])
print('faturamento', mais_lucrativo['faturamento'])
# Out:
# O produto com maior faturamento Mochila
# faturamento 1348.5
