# %% [markdown]
# <a href="https://colab.research.google.com/github/lucaslaurindo/Python/blob/main/if%26else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ESTRUTURAS CONDICIONAIS IF & ELSE

# %%
idade = int(input('Digite sua idade: '))
if idade >= 18:
    print('Apto para voto. ')

else: print('Não apto. ')
# Out:
# Digite sua idade: 11
# Não apto.

# %% [markdown]
# DESAFIO IF & ELSE

# %%
nome = input('Digite seu nome: ')
print(f'Olá, {nome}.')

senha = input('Digite a Senha de acesso')
if senha == 'senai2026':
  print(f'Muito bem {nome}! acesso liberado! ')
else: print('acesso negado! ')
# Out:
# Digite seu nome: lucas
# Olá, lucas.
# Digite a Senha de acessosenai2026
# Muito bem lucas! acesso liberado!

# %%
nome = input('Digite seu nome: ')
print(f'Olá, {nome}.')

venda = int(input('Digite seu valor total em vendas: '))
if venda >= 8000:
    print('Bateu meta. ')

else: print('meta não atingida! ')
# Out:
# Digite seu nome: joao
# Olá, joao.
# Digite seu valor total em vendas: 15000
# Bateu meta.
